# %%
"""
        http://e201d92f61dd:8888/tree?token=ae82500fb0fa683d15f64d193533ebc5fd865517a158f007
        http://127.0.0.1:8888/tree?token=ae82500fb0fa683d15f64d193533ebc5fd865517a158f007
"""

import mujoco # type: ignore
import torch # pyright: ignore[reportMissingImports]
print("MuJoCo:", mujoco.__version__)
print("GPU:", torch.cuda.is_available())
# Out:
# MuJoCo: 3.3.0
# GPU: True
